# %%
import os
import glob

import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import gamma, expon, norm, boltzmann, beta, bernoulli, binom, uniform, logistic

# %%
path_ldata = os.path.join(os.path.expanduser('~'), 'Neuro-insights', 'data')

# %%
glob_pattern = os.path.join(path_ldata, '**', 'META*.csv')
path_metacsv = glob.glob(glob_pattern, recursive=True)

# %%
df = pd.read_csv(path_metacsv[0], index_col='ID')

# %% [markdown]
# # Fitting the data

# %% [markdown]
# ## Gamma

# %%
a = 5
x = np.linspace(0, 20, 101)

sns.lineplot(x=x, y=gamma.pdf(x, a))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exponential

# %%
sns.lineplot(x=x, y=expon.pdf(x, 0, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **On hypothesis testing:**
#
# - Once equipped with a model, one can do things such as hypothesis testing and computing CIs
# - p value is an important metric; shouldnt be used in isolation - visualizations are a great tool too
#
# https://youtu.be/TE8C-PsZfrw
#
# [Explaining p-values with puppies](https://hackernoon.com/explaining-p-values-with-puppies-af63d68005d0) (no animals hurt)
